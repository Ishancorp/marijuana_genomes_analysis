# %% [markdown]
# # Data input

# %%
import pandas as pd
import numpy as np
import bq_helper
from bq_helper import BigQueryHelper
# https://www.kaggle.com/sohier/introduction-to-the-bq-helper-package
genomes = bq_helper.BigQueryHelper(active_project="bigquery-public-data",
                                   dataset_name="genomics_cannabis")

# %%
bq_assistant = BigQueryHelper("bigquery-public-data", "genomics_cannabis")
bq_assistant.list_tables()
# Out:
# ['MNPR01_201703',
#  'MNPR01_reference_201703',
#  'MNPR01_transcriptome_201703',
#  'cs10_gff',
#  'cs3k_project_info',
#  'cs3k_vcf_cs10_dv090',
#  'sample_info_201703']

# %%
bq_assistant.table_schema("cs3k_project_info")
# Out:
#                   name     type      mode description
# 0           AvgSpotLen  INTEGER  NULLABLE
# 1            BioSample   STRING  NULLABLE
# 2   DATASTORE_provider   STRING  NULLABLE
# 3     DATASTORE_region   STRING  NULLABLE
# 4           Experiment   STRING  NULLABLE
# 5           InsertSize  INTEGER  NULLABLE
# 6        LibraryLayout   STRING  NULLABLE
# 7         Library_Name   STRING  NULLABLE
# 8               MBases  INTEGER  NULLABLE
# 9               MBytes  INTEGER  NULLABLE
# 10                 Run   STRING  NULLABLE
# 11          SRA_Sample   STRING  NULLABLE
# 12         Sample_Name   STRING  NULLABLE
# 13          Assay_Type   STRING  NULLABLE
# 14          BioProject   STRING  NULLABLE
# 15         Center_Name   STRING  NULLABLE
# 16             Consent   STRING  NULLABLE
# 17  DATASTORE_filetype   STRING  NULLABLE
# 18          Instrument   STRING  NULLABLE
# 19    LibrarySelection   STRING  NULLABLE
# 20       LibrarySource   STRING  NULLABLE
# ...

# %%
bq_assistant.head("MNPR01_201703", num_rows=10)
# Out:
#                      reference_name   start     end reference_bases  \
# 0  gi|1098496801|gb|MNPR01000114.1|  318648  318654          TCAAAG
# 1  gi|1098489786|gb|MNPR01004871.1|   11908   11914          CCTTGC
# 2  gi|1098496792|gb|MNPR01000118.1|  348937  348947      CTCAACTTGC
# 3  gi|1098495754|gb|MNPR01000694.1|   72508   72512            GTAG
# 4  gi|1098489564|gb|MNPR01005041.1|    8695    8699            TCAA
# 5  gi|1098493040|gb|MNPR01002808.1|   10232   10238          GGATTG
# 6  gi|1098494910|gb|MNPR01001505.1|    6201    6211      TAAAAAAAAT
# 7  gi|1098496059|gb|MNPR01000497.1|   63172   63177           GGAAG
# 8  gi|1098497076|gb|MNPR01000034.1|  389457  389462           GGGGT
# 9  gi|1098484780|gb|MNPR01007372.1|    8354    8356              GT
#
#   alternate_bases                                         variant_id  \
# 0        [TCGAAG]  CKXG8eKP9qOf8wESIGdpfDEwOTg0OTY4MDF8Z2J8TU5QUj...
# 1        [TTTTGC]  CKXG8eKP9qOf8wESIGdpfDEwOTg0ODk3ODZ8Z2J8TU5QUj...
# ...

# %%
query_top_ten = """SELECT
  *
FROM
  `bigquery-public-data.genomics_cannabis.MNPR01_201703` v
LIMIT 10;"""
response_top_ten = genomes.query_to_pandas_safe(query_top_ten, max_gb_scanned=100)
response_top_ten.columns
# Out:
# C:\Users\sharm\AppData\Roaming\Python\Python311\site-packages\google\cloud\bigquery\table.py:1727: UserWarning: BigQuery Storage module not found, fetch data with the REST endpoint instead.
#   warnings.warn(
# Index(['reference_name', 'start', 'end', 'reference_bases', 'alternate_bases',
#        'variant_id', 'quality', 'filter', 'names', 'call', 'AB', 'ABP', 'AC',
#        'AF', 'AN', 'AO', 'CIGAR', 'DP', 'DPB', 'DPRA', 'EPP', 'EPPR', 'GTI',
#        'LEN', 'MEANALT', 'MQM', 'MQMR', 'NS', 'NUMALT', 'ODDS', 'PAIRED',
#        'PAIREDR', 'PAO', 'PQA', 'PQR', 'PRO', 'QA', 'QR', 'RO', 'RPL', 'RPP',
#        'RPPR', 'RPR', 'RUN', 'SAF', 'SAP', 'SAR', 'SRF', 'SRP', 'SRR', 'TYPE'],
#       dtype='object')

# %%
response_top_ten
# Out:
#                      reference_name   start     end reference_bases  \
# 0  gi|1098496801|gb|MNPR01000114.1|  318648  318654          TCAAAG
# 1  gi|1098489786|gb|MNPR01004871.1|   11908   11914          CCTTGC
# 2  gi|1098496792|gb|MNPR01000118.1|  348937  348947      CTCAACTTGC
# 3  gi|1098495754|gb|MNPR01000694.1|   72508   72512            GTAG
# 4  gi|1098489564|gb|MNPR01005041.1|    8695    8699            TCAA
# 5  gi|1098493040|gb|MNPR01002808.1|   10232   10238          GGATTG
# 6  gi|1098494910|gb|MNPR01001505.1|    6201    6211      TAAAAAAAAT
# 7  gi|1098496059|gb|MNPR01000497.1|   63172   63177           GGAAG
# 8  gi|1098497076|gb|MNPR01000034.1|  389457  389462           GGGGT
# 9  gi|1098484780|gb|MNPR01007372.1|    8354    8356              GT
#
#   alternate_bases                                         variant_id  \
# 0        [TCGAAG]  CKXG8eKP9qOf8wESIGdpfDEwOTg0OTY4MDF8Z2J8TU5QUj...
# 1        [TTTTGC]  CKXG8eKP9qOf8wESIGdpfDEwOTg0ODk3ODZ8Z2J8TU5QUj...
# ...

# %%
query_reduced = """SELECT
  variant_id, alternate_bases, quality, RPPR, type, len, cigar
FROM
  `bigquery-public-data.genomics_cannabis.MNPR01_201703` v
limit 10;"""
response_reduced = genomes.query_to_pandas_safe(query_reduced, max_gb_scanned=100)
response_reduced.head(10)
# Out:
# C:\Users\sharm\AppData\Roaming\Python\Python311\site-packages\google\cloud\bigquery\table.py:1727: UserWarning: BigQuery Storage module not found, fetch data with the REST endpoint instead.
#   warnings.warn(
#                                           variant_id alternate_bases  \
# 0  CKXG8eKP9qOf8wESIGdpfDEwOTg0OTY4NTZ8Z2J8TU5QUj...           [TTC]
# 1  CKXG8eKP9qOf8wESIGdpfDEwOTg0OTYyOTB8Z2J8TU5QUj...        [AATAGA]
# 2  CKXG8eKP9qOf8wESIGdpfDEwOTg0ODczMDV8Z2J8TU5QUj...           [ACA]
# 3  CKXG8eKP9qOf8wESIGdpfDEwOTg0OTY2MTd8Z2J8TU5QUj...          [CAGT]
# 4  CKXG8eKP9qOf8wESIGdpfDEwOTg0OTU4NTl8Z2J8TU5QUj...   [AAAAAAAAAAA]
# 5  CKXG8eKP9qOf8wESIGdpfDEwOTg0OTYzNzR8Z2J8TU5QUj...        [AGAGAG]
# 6  CKXG8eKP9qOf8wESIGdpfDEwOTg0OTY2MDZ8Z2J8TU5QUj...           [CAA]
# 7  CKXG8eKP9qOf8wESIGdpfDEwOTg0OTE0NDd8Z2J8TU5QUj...         [AATCG]
# 8  CKXG8eKP9qOf8wESIGdpfDEwOTg0OTU3MzF8Z2J8TU5QUj...          [GGTA]
# 9  CKXG8eKP9qOf8wESIGdpfDEwOTg0OTUzNjV8Z2J8TU5QUj...      [GATAGAAG]
#
# ...

# %% [markdown]
# alternate_bases consists of genes of the variant, while type means type of genetic variation. All the various random letter combinations represent proteins.

# %% [markdown]
# Proteins are: 'AB', 'ABP', 'AC', 'AF', 'AN', 'AO', 'DP', 'DPB', 'DPRA', 'EPP', 'EPPR', 'GTI', 'MQM', 'MQMR', 'NS', 'PAO', 'PQA', 'PQR', 'PRO', 'QA', 'QR', 'RO', 'RPL', 'RPP', 'RPPR', 'RPR', 'RUN', 'SAF', 'SAP', 'SAR', 'SRF', 'SRP', 'SRR'

# %%
query_projinfo = """SELECT
  *
FROM
  `bigquery-public-data.genomics_cannabis.cs3k_project_info` v
limit 10;"""
response_projinfo = genomes.query_to_pandas_safe(query_projinfo, max_gb_scanned=100)
response_projinfo.head(10)
# Out:
# C:\Users\sharm\AppData\Roaming\Python\Python311\site-packages\google\cloud\bigquery\table.py:1727: UserWarning: BigQuery Storage module not found, fetch data with the REST endpoint instead.
#   warnings.warn(
#    AvgSpotLen BioSample DATASTORE_provider DATASTORE_region Experiment  \
# 0        <NA>  RSP10411               None             None       None
# 1        <NA>  RSP10156               None             None       None
# 2        <NA>  RSP10072               None             None       None
# 3        <NA>  RSP10084               None             None       None
# 4        <NA>  RSP10103               None             None       None
# 5        <NA>  RSP10107               None             None       None
# 6        <NA>  RSP10159               None             None       None
# 7        <NA>  RSP10559               None             None       None
# 8        <NA>  RSP10605               None             None       None
# ...

# %%
response_projinfo.columns
# Out:
# Index(['AvgSpotLen', 'BioSample', 'DATASTORE_provider', 'DATASTORE_region',
#        'Experiment', 'InsertSize', 'LibraryLayout', 'Library_Name', 'MBases',
#        'MBytes', 'Run', 'SRA_Sample', 'Sample_Name', 'Assay_Type',
#        'BioProject', 'Center_Name', 'Consent', 'DATASTORE_filetype',
#        'Instrument', 'LibrarySelection', 'LibrarySource', 'LoadDate',
#        'Organism', 'Platform', 'ReleaseDate', 'SRA_Study'],
#       dtype='object')

# %%
query_reference = """SELECT
  *
FROM
  `bigquery-public-data.genomics_cannabis.cs3k_project_info` v
limit 10;"""
response_reference = genomes.query_to_pandas_safe(query_reference, max_gb_scanned=100)
response_reference.head(10)
# Out:
# C:\Users\sharm\AppData\Roaming\Python\Python311\site-packages\google\cloud\bigquery\table.py:1727: UserWarning: BigQuery Storage module not found, fetch data with the REST endpoint instead.
#   warnings.warn(
#    AvgSpotLen BioSample DATASTORE_provider DATASTORE_region Experiment  \
# 0        <NA>  RSP10411               None             None       None
# 1        <NA>  RSP10156               None             None       None
# 2        <NA>  RSP10072               None             None       None
# 3        <NA>  RSP10084               None             None       None
# 4        <NA>  RSP10103               None             None       None
# 5        <NA>  RSP10107               None             None       None
# 6        <NA>  RSP10159               None             None       None
# 7        <NA>  RSP10559               None             None       None
# 8        <NA>  RSP10605               None             None       None
# ...

# %%
response_reference.columns
# Out:
# Index(['AvgSpotLen', 'BioSample', 'DATASTORE_provider', 'DATASTORE_region',
#        'Experiment', 'InsertSize', 'LibraryLayout', 'Library_Name', 'MBases',
#        'MBytes', 'Run', 'SRA_Sample', 'Sample_Name', 'Assay_Type',
#        'BioProject', 'Center_Name', 'Consent', 'DATASTORE_filetype',
#        'Instrument', 'LibrarySelection', 'LibrarySource', 'LoadDate',
#        'Organism', 'Platform', 'ReleaseDate', 'SRA_Study'],
#       dtype='object')

# %%
query_transcript = """SELECT
  *
FROM
  `bigquery-public-data.genomics_cannabis.MNPR01_transcriptome_201703` v
limit 10;"""
response_transcript = genomes.query_to_pandas_safe(query_transcript, max_gb_scanned=100)
response_transcript.head(10)
# Out:
# C:\Users\sharm\AppData\Roaming\Python\Python311\site-packages\google\cloud\bigquery\table.py:1727: UserWarning: BigQuery Storage module not found, fetch data with the REST endpoint instead.
#   warnings.warn(
#                      reference_name   start     end    reference_bases  \
# 0  gi|1098491042|gb|MNPR01004128.1|   26792   26801          TAAAAAAAC
# 1  gi|1098496788|gb|MNPR01000120.1|  303490  303494               GGGG
# 2  gi|1098492898|gb|MNPR01002935.1|   15946   15949                ATT
# 3  gi|1098489712|gb|MNPR01004926.1|   15709   15719         CAGCTTGCAA
# 4  gi|1098493680|gb|MNPR01002267.1|   30017   30034  CTTTTTTTTTTTTTTTC
# 5  gi|1098494274|gb|MNPR01001840.1|   83432   83438             GTGATA
# 6  gi|1098494049|gb|MNPR01002008.1|   42790   42800         CATAACTATT
# 7  gi|1098495883|gb|MNPR01000585.1|  135282  135286               GCAT
# 8  gi|1098495008|gb|MNPR01001427.1|  108487  108491               TGAT
# ...

# %%
response_transcript.columns
# Out:
# Index(['reference_name', 'start', 'end', 'reference_bases', 'alternate_bases',
#        'variant_id', 'quality', 'filter', 'names', 'call', 'AB', 'ABP', 'AC',
#        'AF', 'AN', 'AO', 'CIGAR', 'DP', 'DPB', 'DPRA', 'EPP', 'EPPR', 'GTI',
#        'LEN', 'MEANALT', 'MQM', 'MQMR', 'NS', 'NUMALT', 'ODDS', 'PAIRED',
#        'PAIREDR', 'PAO', 'PQA', 'PQR', 'PRO', 'QA', 'QR', 'RO', 'RPL', 'RPP',
#        'RPPR', 'RPR', 'RUN', 'SAF', 'SAP', 'SAR', 'SRF', 'SRP', 'SRR', 'TYPE'],
#       dtype='object')

# %%
query_gff = """SELECT
  *
FROM
  `bigquery-public-data.genomics_cannabis.cs10_gff` v
limit 10;"""
response_gff = genomes.query_to_pandas_safe(query_gff, max_gb_scanned=100)
response_gff.head(10)
# Out:
# C:\Users\sharm\AppData\Roaming\Python\Python311\site-packages\google\cloud\bigquery\table.py:1727: UserWarning: BigQuery Storage module not found, fetch data with the REST endpoint instead.
#   warnings.warn(
#                    id          seq_id  source type   start     end  \
# 0  cds-XP_030485339.1  NW_022060368.1  Gnomon  CDS  134162  134291
# 1  cds-XP_030485339.1  NW_022060368.1  Gnomon  CDS  132946  133639
# 2  cds-XP_030485339.1  NW_022060368.1  Gnomon  CDS  134441  134606
# 3  cds-XP_030485340.1  NW_022060368.1  Gnomon  CDS   10897   11589
# 4  cds-XP_030485340.1  NW_022060368.1  Gnomon  CDS   12720   13374
# 5  cds-XP_030485340.1  NW_022060368.1  Gnomon  CDS   11671   12632
# 6  cds-XP_030485341.1  NW_022060368.1  Gnomon  CDS  124185  124513
# 7  cds-XP_030485341.1  NW_022060368.1  Gnomon  CDS  123814  124101
# 8  cds-XP_030485341.1  NW_022060368.1  Gnomon  CDS  123630  123716
# 9  cds-XP_030485341.1  NW_022060368.1  Gnomon  CDS  124593  124769
#
# ...

# %%
response_gff.columns
# Out:
# Index(['id', 'seq_id', 'source', 'type', 'start', 'end', 'geometry', 'score',
#        'strand', 'phase', 'attributes', 'derived_features', 'child_features',
#        '_part'],
#       dtype='object')

# %%
query_vcf = """SELECT
  *
FROM
  `bigquery-public-data.genomics_cannabis.cs3k_vcf_cs10_dv090` v
limit 10;"""
response_vcf = genomes.query_to_pandas_safe(query_vcf, max_gb_scanned=100)
response_vcf.head(10)
# Out:
# C:\Users\sharm\AppData\Roaming\Python\Python311\site-packages\google\cloud\bigquery\table.py:1727: UserWarning: BigQuery Storage module not found, fetch data with the REST endpoint instead.
#   warnings.warn(
#   reference_name  start_position  end_position  \
# 0        ctgX111           16279         16280
# 1        ctgX111           16279         16280
# 2        ctgX111           16279         16280
# 3        ctgX111           17691         17692
# 4        ctgX111           20867         20868
# 5        ctgX111           25432         25433
# 6        ctgX111           25432         25433
# 7        ctgX111           25432         25433
# 8        ctgX111           21072         21073
# 9        ctgX111           16280         16281
#
#                                geometry reference_bases alternate_bases names  \
# 0   LINESTRING(0.0016279 0, 0.001628 0)               G  [{'alt': 'A'}]    []
# 1   LINESTRING(0.0016279 0, 0.001628 0)               G  [{'alt': 'A'}]    []
# ...

# %%
response_vcf.columns
# Out:
# Index(['reference_name', 'start_position', 'end_position', 'geometry',
#        'reference_bases', 'alternate_bases', 'names', 'quality', 'filter',
#        'call', '_part'],
#       dtype='object')

# %%
query_sample = """SELECT
  *
FROM
  `bigquery-public-data.genomics_cannabis.sample_info_201703` v
limit 10;"""
response_sample = genomes.query_to_pandas_safe(query_sample, max_gb_scanned=100)
response_sample.head(10)
# Out:
# C:\Users\sharm\AppData\Roaming\Python\Python311\site-packages\google\cloud\bigquery\table.py:1727: UserWarning: BigQuery Storage module not found, fetch data with the REST endpoint instead.
#   warnings.warn(
#   SRA_Sample_s       Sample_Name_s cultivar_s Library_Name_s
# 0    SRS266493        CS-USO31-DNA       None    CS-US_SIL-1
# 1    SRS266493        CS-USO31-DNA       None    CS-US_SIL-2
# 2    SRS266493        CS-USO31-DNA       None    CS-US_SIL-1
# 3    SRS266493        CS-USO31-DNA       None    CS-US_SIL-2
# 4    SRS266713       CS-FINOLA-DNA       None    CS-FN_SIL-1
# 5    SRS266713       CS-FINOLA-DNA       None    CS-FN_SIL-2
# 6    SRS266713       CS-FINOLA-DNA       None    CS-FN_SIL-1
# 7    SRS266713       CS-FINOLA-DNA       None    CS-FN_SIL-2
# 8    SRS266735  CS-FINOLA-RNA-MFLW       None        FN-MFLW
# 9    SRS266735  CS-FINOLA-RNA-MFLW       None        FN-MFLW

# %%
response_sample.columns
# Out:
# Index(['SRA_Sample_s', 'Sample_Name_s', 'cultivar_s', 'Library_Name_s'], dtype='object')
